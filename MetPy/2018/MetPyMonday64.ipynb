# %% [markdown]
# ## 64 - Night Shading
#
# Watich video: [YouTube](https://www.youtube.com/watch?v=-Gr5n9h5Q5c)

# %%
import datetime
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.feature.nightshade import Nightshade
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
fig = plt.figure(1, figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
valid = datetime.datetime(2018, 12, 4, 5, 0, 0)
ax.stock_img()
ax.add_feature(Nightshade(valid), alpha=0.75)
ax.set_title(f'VALID: {valid}')
plt.show()

# %%
fig = plt.figure(2, figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.Robinson())
valid = datetime.datetime(2018, 12, 4, 5, 0, 0)
ax.stock_img()
ax.add_feature(Nightshade(valid), alpha=0.75)
ax.set_title(f'VALID: {valid}')
plt.show()

# %%
fig = plt.figure(3, figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.EquidistantConic())
valid = datetime.datetime(2018, 12, 4, 5, 0, 0)
ax.stock_img()
ax.add_feature(Nightshade(valid), alpha=0.75)
ax.set_title(f'VALID: {valid}')
plt.show()
